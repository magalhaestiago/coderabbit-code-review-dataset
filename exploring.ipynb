# %%
import pandas as pd

# %%
repositories = pd.read_parquet('results/repositories.parquet')
pull_requests = pd.read_parquet('results/pull_requests.parquet')
issues = pd.read_parquet('results/issues.parquet')
commits = pd.read_parquet('results/commits.parquet')

# %%
print("Repositories shape:", repositories.shape)
print("Pull requests shape:", pull_requests.shape)
print("Issues shape:", issues.shape)
print("Commits shape:", commits.shape)
# Out:
# Repositories shape: (481, 14)
# Pull requests shape: (99454, 14)
# Issues shape: (2255, 12)
# Commits shape: (188, 10)

# %%
repositories.columns
# Out:
# Index(['repo_id', 'repo_name', 'coderabbit_method_heuristic', 'mined_at',
#        'github_link', 'language', 'license', 'created_at', 'commits', 'forks',
#        'watchers', 'stargazers', 'contributors', 'topics'],
#       dtype='str')

# %%
pull_requests.columns
# Out:
# Index(['repo_id', 'repo', 'pr_id', 'pr_number', 'title', 'url', 'state',
#        'author', 'created_at', 'updated_at', 'closed_at', 'labels', 'comments',
#        'coderabbit_activity'],
#       dtype='str')

# %%
issues.columns
# Out:
# Index(['repo_id', 'repo', 'issue_number', 'title', 'url', 'state', 'author',
#        'created_at', 'updated_at', 'closed_at', 'labels', 'comments'],
#       dtype='str')

# %%
commits.columns
# Out:
# Index(['repo_id', 'repo', 'pr_id', 'pr_number', 'sha', 'message',
#        'commit_activity_type', 'author_name', 'author_date', 'url'],
#       dtype='str')

# %%
commits['commit_activity_type'].value_counts()
# Out:
# commit_activity_type
# generate docstrings        111
# autofix                     43
# Other                       22
# generate unit tests          9
# resolve merge conflicts      3
# Name: count, dtype: int64

# %%
pull_requests['coderabbit_activity'].value_counts()
# Out:
# coderabbit_activity
# Reviewed                                            99275
# Authored: generate docstrings                          57
# Reviewed, Authored: generate docstrings                49
# Reviewed, Authored: autofix                            35
# Reviewed, Authored: Other                              14
# Authored: Other                                         6
# Reviewed, Authored: generate unit tests                 5
# Authored: generate unit tests                           3
# Reviewed, Authored: autofix, generate docstrings        3
# Reviewed, Authored: resolve merge conflicts             3
# Authored: autofix                                       3
# Authored: generate unit tests, Other                    1
# Name: count, dtype: int64

# %%
pull_requests[pull_requests['coderabbit_activity'].str.contains('Other')]['title'].value_counts()
# Out:
# title
# 📝 CodeRabbit Chat: Implement requested code changes                                                  3
# 📝 CodeRabbit Chat: Update .coderabbit.yaml to filter for main and 2024b branches only                2
# ✨ Changed staff token perms to match user auth                                                       1
# chore(release): 1.15.0                                                                               1
# fix: enhance API snippet generation with file upload support and consistent authentication           1
# 📝 CodeRabbit Chat: Remove conflicting AsRef<Self> implementation for PyObject in core.rs             1
# CodeRabbit Generated Unit Tests: Add comprehensive unit tests for AES-GCM, stream, and raw_stream    1
# refactor(subs): use validationissues                                                                 1
# 📝 Add docstrings to `ystade/qdmi-sc-device`                                                          1
# [Gemma4] Add MoE Calibration Support                                                                 1
# [AWQ] Update MoE mappings to include router in balance layers                                        1
# Add JSON-LD for Dataset to improve discoverability                                                   1
# fix: restore old-style YAML groups expansion                                                         1
# chore: release 2026-03-27                                                                            1
# feat: allow message block edition                                                                    1
# fix #1087 env_file_load not working with multiple variables                                          1
# feat(stdlib): implement `text_find` to use within `env_file_load`                                    1
# chore: improve tests                                                                                 1
# Name: count, dtype: int64

# %%
pull_requests[pull_requests['coderabbit_activity'].str.contains('Other')]
# Out:
#        repo_id                                     repo       pr_id  \
# 6258       270                           tryghost/ghost   270_23585
# 8040       546                         voxel51/fiftyone    546_7343
# 12927      546                         voxel51/fiftyone    546_7343
# 13050      546                         voxel51/fiftyone    546_7458
# 16592     1066                     langflow-ai/langflow   1066_9018
# 17681     1169                    rustpython/rustpython   1169_5899
# 50425     4317                           nanomq/nanonng   4317_1386
# 54594     4999                    openmeterio/openmeter   4999_3058
# 58304     6262              munich-quantum-toolkit/core   6262_1329
# 61709     6713                 opendatahub-io/notebooks   6713_1491
# 62372     6713                 opendatahub-io/notebooks   6713_1491
# 70263     9025              vllm-project/llm-compressor   9025_2565
# 70275     9025              vllm-project/llm-compressor   9025_2451
# 70709     9025              vllm-project/llm-compressor   9025_2572
# 78896    11247           digital-land/digital-land.info   11247_434
# 82699    12905              alandtse/alexa_media_player  12905_3446
# 82706    12905              alandtse/alexa_media_player  12905_3414
# 91411    19689                   SigmaNight/basiliskLLM   19689_590
# 96924    28207                         amber-lang/amber  28207_1096
# 96950    28207                         amber-lang/amber  28207_1104
# 98144    33094  martin-georgiev/postgresql-for-doctrine   33094_340
#
#        pr_number                                              title  \
# 6258       23585     ✨ Changed staff token perms to match user auth
# 8040        7343  📝 CodeRabbit Chat: Implement requested code ch...
# 12927       7343  📝 CodeRabbit Chat: Implement requested code ch...
# 13050       7458                             chore(release): 1.15.0
# 16592       9018  fix: enhance API snippet generation with file ...
# 17681       5899  📝 CodeRabbit Chat: Remove conflicting AsRef<Se...
# 50425       1386  CodeRabbit Generated Unit Tests: Add comprehen...
# 54594       3058               refactor(subs): use validationissues
# 58304       1329        📝 Add docstrings to `ystade/qdmi-sc-device`
# 61709       1491  📝 CodeRabbit Chat: Update .coderabbit.yaml to ...
# 62372       1491  📝 CodeRabbit Chat: Update .coderabbit.yaml to ...
# 70263       2565               [Gemma4] Add MoE Calibration Support
# 70275       2451  [AWQ] Update MoE mappings to include router in...
# 70709       2572  📝 CodeRabbit Chat: Implement requested code ch...
# 78896        434  Add JSON-LD for Dataset to improve discoverabi...
# 82699       3446       fix: restore old-style YAML groups expansion
# 82706       3414                          chore: release 2026-03-27
# 91411        590                  feat: allow message block edition
# 96924       1096  fix #1087 env_file_load not working with multi...
# 96950       1104  feat(stdlib): implement `text_find` to use wit...
# 98144        340                               chore: improve tests
#
#                                                      url   state  \
# 6258        https://github.com/TryGhost/Ghost/pull/23585  closed
# 8040       https://github.com/voxel51/fiftyone/pull/7343  closed
# 12927      https://github.com/voxel51/fiftyone/pull/7343  closed
# 13050      https://github.com/voxel51/fiftyone/pull/7458  closed
# 16592  https://github.com/langflow-ai/langflow/pull/9018  closed
# 17681  https://github.com/RustPython/RustPython/pull/...  closed
# 50425        https://github.com/nanomq/NanoNNG/pull/1386  closed
# 54594  https://github.com/openmeterio/openmeter/pull/...  closed
# 58304  https://github.com/munich-quantum-toolkit/core...  closed
# 61709  https://github.com/opendatahub-io/notebooks/pu...  closed
# 62372  https://github.com/opendatahub-io/notebooks/pu...  closed
# 70263  https://github.com/vllm-project/llm-compressor...  closed
# 70275  https://github.com/vllm-project/llm-compressor...  closed
# 70709  https://github.com/vllm-project/llm-compressor...  closed
# 78896  https://github.com/digital-land/digital-land.i...  closed
# 82699  https://github.com/alandtse/alexa_media_player...  closed
# 82706  https://github.com/alandtse/alexa_media_player...  closed
# 91411  https://github.com/SigmaNight/basiliskLLM/pull...  closed
# 96924      https://github.com/amber-lang/amber/pull/1096  closed
# 96950      https://github.com/amber-lang/amber/pull/1104  closed
# 98144  https://github.com/martin-georgiev/postgresql-...  closed
#
#                   author            created_at            updated_at  \
# 6258              ErisDS  2025-05-29T07:59:08Z  2025-05-29T09:53:59Z
# 8040   coderabbitai[bot]  2026-04-09T19:59:52Z  2026-04-09T21:19:41Z
# 12927  coderabbitai[bot]  2026-04-09T19:59:52Z  2026-04-09T21:19:41Z
# 13050          mo-getter  2026-05-01T19:44:01Z  2026-05-01T22:06:43Z
# 16592        namastex888  2025-07-11T17:53:21Z  2025-07-23T15:21:18Z
# 17681  coderabbitai[bot]  2025-07-04T01:39:45Z  2025-07-04T02:40:32Z
# 50425  coderabbitai[bot]  2025-12-18T09:38:32Z  2025-12-24T08:09:49Z
# 54594           GAlexIHU  2025-06-30T15:36:24Z  2025-07-02T11:58:30Z
# 58304  coderabbitai[bot]  2025-11-24T11:59:50Z  2025-11-24T12:17:24Z
# 61709  coderabbitai[bot]  2025-07-23T08:06:19Z  2025-07-23T09:18:24Z
# 62372  coderabbitai[bot]  2025-07-23T08:06:19Z  2025-07-23T09:18:24Z
# 70263             dsikka  2026-04-05T21:10:37Z  2026-04-07T14:00:45Z
# 70275   brian-dellabetta  2026-03-06T19:36:26Z  2026-04-24T21:06:22Z
# 70709  coderabbitai[bot]  2026-04-06T21:35:58Z  2026-04-06T22:31:47Z
# 78896      stevenjmesser  2025-08-27T11:27:59Z  2025-08-27T13:44:41Z
# 82699      danielbrunt57  2026-05-07T23:11:41Z  2026-05-09T17:46:38Z
# 82706           alandtse  2026-03-22T07:13:18Z  2026-03-28T02:57:28Z
# 91411         clementb49  2025-03-15T23:20:44Z  2025-06-21T09:13:01Z
# 96924         Tirito6626  2026-05-11T16:44:30Z  2026-06-13T17:15:16Z
# 96950  coderabbitai[bot]  2026-05-19T20:42:42Z  2026-05-31T18:36:19Z
# 98144    martin-georgiev  2025-04-11T01:25:58Z  2025-04-11T13:38:15Z
#
#                   closed_at  \
# 6258   2025-05-29T09:53:57Z
# 8040   2026-04-09T21:19:40Z
# 12927  2026-04-09T21:19:40Z
# 13050  2026-05-01T22:06:41Z
# 16592  2025-07-17T23:47:01Z
# 17681  2025-07-04T02:40:30Z
# 50425  2025-12-24T08:09:45Z
# 54594  2025-07-02T11:58:28Z
# 58304  2025-11-24T12:14:29Z
# 61709  2025-07-23T09:18:22Z
# 62372  2025-07-23T09:18:22Z
# 70263  2026-04-07T14:00:43Z
# 70275  2026-04-24T21:06:20Z
# 70709  2026-04-06T22:31:46Z
# 78896  2025-08-27T13:44:37Z
# 82699  2026-05-09T06:33:22Z
# 82706  2026-03-27T08:40:49Z
# 91411  2025-06-21T09:12:59Z
# 96924  2026-06-13T17:15:15Z
# 96950  2026-05-31T18:36:19Z
# 98144  2025-04-11T13:38:13Z
#
#                                                   labels  comments  \
# 6258                                                  []        11
# 8040                                                  []         1
# 12927                                                 []         1
# 13050                                                 []         1
# 16592  [bug, javascript, size:XXL, lgtm, feature, com...        15
# 17681                                                 []         1
# 50425                                                 []         1
# 54594                                [release-note/misc]         1
# 58304                                                 []         1
# 61709  [approved, ok-to-test, tide/merge-method-squas...        12
# 62372  [approved, ok-to-test, tide/merge-method-squas...        12
# 70263                                            [ready]        12
# 70275  [enhancement, ready, awq, transforms, two-revi...        19
# 70709                                    [documentation]         1
# 78896                                                 []        13
# 82699                                      [alexa_media]        10
# 82706  [enhancement, alexapy, dependencies, alexa_media]         7
# 91411                                                 []         3
# 96924                                                 []         8
# 96950                                                 []         2
# 98144                                                 []         1
#
#                         coderabbit_activity
# 6258              Reviewed, Authored: Other
# 8040                        Authored: Other
# 12927             Reviewed, Authored: Other
# 13050             Reviewed, Authored: Other
# 16592             Reviewed, Authored: Other
# 17681                       Authored: Other
# 50425  Authored: generate unit tests, Other
# 54594             Reviewed, Authored: Other
# 58304                       Authored: Other
# 61709                       Authored: Other
# 62372             Reviewed, Authored: Other
# 70263             Reviewed, Authored: Other
# 70275             Reviewed, Authored: Other
# 70709                       Authored: Other
# 78896             Reviewed, Authored: Other
# 82699             Reviewed, Authored: Other
# 82706             Reviewed, Authored: Other
# 91411             Reviewed, Authored: Other
# 96924             Reviewed, Authored: Other
# 96950                       Authored: Other
# 98144             Reviewed, Authored: Other

# %%
commits[commits['commit_activity_type'] == 'Other']['message'].value_counts()
# Out:
# message
# 📝 CodeRabbit Chat: Implement requested code changes                                                                                                                                                                                                                                                                                                                                      8
# 📝 CodeRabbit Chat: Update admin middleware in core/server/web/api/endpoints/admin/middleware.js                                                                                                                                                                                                                                                                                          2
# 📝 CodeRabbit Chat: Update admin middleware in server web API endpoints                                                                                                                                                                                                                                                                                                                   1
# 📝 CodeRabbit Chat: Fix curl file upload commands for ChatInput and File/VideoFile APIs                                                                                                                                                                                                                                                                                                   1
# 📝 CodeRabbit Chat: Remove conflicting AsRef<Self> implementation for PyObject in core.rs                                                                                                                                                                                                                                                                                                 1
# Fix UTG issues (iteration 1)                                                                                                                                                                                                                                                                                                                                                             1
# 📝 CodeRabbit Chat: Replace 'var' with 'const' in variable declaration at line 103                                                                                                                                                                                                                                                                                                        1
# 📝 CodeRabbit Chat: Update .coderabbit.yaml to filter for main and 2024b branches only                                                                                                                                                                                                                                                                                                    1
# 📝 CodeRabbit Chat: Implement requested code changes (#2572)\n\nCode changes was requested by @dsikka.\n\n*\nhttps://github.com/vllm-project/llm-compressor/pull/2565#discussion_r3041816018\n\nThe following files were modified:\n\n* `examples/quantization_w8a8_fp8/gemma4_example.py`\n\nCo-authored-by: coderabbitai[bot] <136622811+coderabbitai[bot]@users.noreply.github.com>    1
# 📝 CodeRabbit Chat: Add pytest tests for dataset template in hermetic Jinja2 env                                                                                                                                                                                                                                                                                                          1
# fix: login reauth, DND cooldown, task cleanup (#3422)                                                                                                                                                                                                                                                                                                                                    1
# 📝 CodeRabbit Chat: Add initial test files for various Basilisk modules and components                                                                                                                                                                                                                                                                                                    1
# feat(stdlib): implement `text_find` to use within `env_file_load` (#1104)\n\n* 📝 CodeRabbit Chat: Implement requested code changes\n\n* Update env.ab\n\n* Update env.ab\n\n---------\n\nCo-authored-by: coderabbitai[bot] <136622811+coderabbitai[bot]@users.noreply.github.com>\nCo-authored-by: Tirito <easycraft250@gmail.com>                                                       1
# 📝 CodeRabbit Chat: Update tests/MartinGeorgiev/Doctrine/DBAL/Types/InetArrayTest.php                                                                                                                                                                                                                                                                                                     1
# Name: count, dtype: int64

# %%
commits[commits['commit_activity_type'] == 'Other']['url'].value_counts()
# Out:
# url
# https://github.com/voxel51/fiftyone/commit/ecf112d02d8eefa1ef9c17b772f514a74d5d9f5c                           2
# https://github.com/TryGhost/Ghost/commit/01797c5c0edb19663352b5d441a4cb35c7cd3b2d                             1
# https://github.com/TryGhost/Ghost/commit/84e3c3b547cf41e866876d1b8f810df10fc059cc                             1
# https://github.com/TryGhost/Ghost/commit/72856aa44a599186e2f8d3a95d836936fc64d853                             1
# https://github.com/langflow-ai/langflow/commit/00c8b5f3467fbe3a620fe7fafde96140c71d7dbf                       1
# https://github.com/RustPython/RustPython/commit/ce185f22edea5f5c33b012b40e896f26ad02d44c                      1
# https://github.com/nanomq/NanoNNG/commit/9220b4af56783e5e9fe5351345eae80fa6924801                             1
# https://github.com/openmeterio/openmeter/commit/409945a8bd658a23dd58fd90b018bb243fb57262                      1
# https://github.com/opendatahub-io/notebooks/commit/00865f3ca4c8e220111ff7c2ce1a24beefcbd36a                   1
# https://github.com/vllm-project/llm-compressor/commit/2fab08a0ddc4270bae90e0beccc58bf9b7f4f580                1
# https://github.com/vllm-project/llm-compressor/commit/bc4b42130a78cac19a358c5db2b87b770e87c78d                1
# https://github.com/vllm-project/llm-compressor/commit/021ed7ee0e0f52f706d1f58bfcc159c0c3ec2653                1
# https://github.com/vllm-project/llm-compressor/commit/c31e0333e5a9a1d2c1f6f4065d6aa36824e3b5b0                1
# https://github.com/vllm-project/llm-compressor/commit/703554b6e7be2f8c54976d791228430677efa22d                1
# https://github.com/digital-land/digital-land.info/commit/7557b55e738c219a83c0ff43f78bdbd7c686e230             1
# https://github.com/alandtse/alexa_media_player/commit/fcfd30e185099e6c8a70d2d04e3bfd36a472a928                1
# https://github.com/alandtse/alexa_media_player/commit/1a9975b015bdf6692945e68d0c5811b22af0e472                1
# https://github.com/SigmaNight/basiliskLLM/commit/1e271af01e430d3e9bc613f5c30a72730daa8ad6                     1
# https://github.com/amber-lang/amber/commit/e0c81d3231f8dd317ea207244516b9bb56a0ea33                           1
# https://github.com/amber-lang/amber/commit/4e5b31b0d413e736cbdf2ccf7b2491ee1510a27b                           1
# https://github.com/martin-georgiev/postgresql-for-doctrine/commit/d56f1f0ffb15c86b61fba86dcede56932078ae2a    1
# Name: count, dtype: int64

# %%
commits[commits['commit_activity_type'] == 'Other']['message'].shape
# Out:
# (22,)

# %%
pull_requests[pull_requests['coderabbit_activity'] != 'Reviewed'].shape
# Out:
# (179, 14)

# %%
issues.head()
# Out:
#    repo_id                           repo  issue_number  \
# 0       29           mantidproject/mantid         40517
# 1      171  opensearch-project/opensearch         20322
# 2      171  opensearch-project/opensearch         20310
# 3      171  opensearch-project/opensearch         20309
# 4      171  opensearch-project/opensearch         20289
#
#                                                title  \
# 0                  Wrong beam current in sample logs
# 1        [BUG] Derived Source breaks on nested field
# 2  [AUTOCUT] Distribution Build Failed for OpenSe...
# 3                    [RELEASE] Release version 3.5.0
# 4  [Feature Request] Make includes publicly acces...
#
#                                                  url   state  \
# 0  https://github.com/mantidproject/mantid/issues...  closed
# 1  https://github.com/opensearch-project/OpenSear...  closed
# 2  https://github.com/opensearch-project/OpenSear...  closed
# 3  https://github.com/opensearch-project/OpenSear...  closed
# 4  https://github.com/opensearch-project/OpenSear...  closed
#
#                         author            created_at            updated_at  \
# 0             GuiMacielPereira  2025-12-18T16:53:01Z  2026-05-11T15:21:19Z
# 1                franco-martin  2025-12-24T18:20:35Z  2026-01-12T16:59:30Z
# 2            opensearch-ci-bot  2025-12-23T02:56:20Z  2025-12-24T02:38:14Z
# 3  opensearch-trigger-bot[bot]  2025-12-23T01:34:14Z  2026-02-12T15:47:10Z
# 4              buddharajusahil  2025-12-19T18:20:14Z  2025-12-23T18:19:39Z
#
#               closed_at                                             labels  \
# 0  2026-05-11T15:21:18Z  [High Priority, Bug, Reported By User, ISIS: E...
# 1  2026-01-12T16:59:30Z                [bug, untriaged, missing-component]
# 2  2025-12-24T02:38:14Z                       [untriaged, autocut, v3.5.0]
# 3  2026-02-12T15:47:09Z                                           [v3.5.0]
# 4  2025-12-23T18:19:39Z            [enhancement, untriaged, _No response_]
#
#    comments
# 0         4
# 1         5
# 2         2
# 3         4
# 4         1
